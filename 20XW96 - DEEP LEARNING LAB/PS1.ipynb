# %% [markdown]
# # PROBLEM SHEET 1

# %%
# 1
import numpy as np
import matplotlib.pyplot as plt

# 2
import scipy.stats as stats

# %%
# 1
np.linalg.solve(np.array([[1, 1], [3, 2]]), np.array([6, 16]))
# Out:
# array([4., 2.])

# %%
x = np.linspace(0, 5, 100)
y1 = 6 - x
y2 = (16 - 3*x) / 2

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# So it might seem numpy was not lying.

# %%
# 2

x = np.random.binomial(n=10, p=0.5, size=100)
plt.hist(x)
plt.show()
x
# Out:
# array([4, 4, 5, 4, 3, 5, 5, 2, 5, 5, 4, 7, 2, 4, 2, 5, 5, 5, 2, 4, 3, 3,
#        6, 6, 6, 6, 2, 5, 7, 5, 7, 6, 4, 7, 3, 6, 7, 5, 2, 4, 4, 9, 4, 5,
#        3, 5, 7, 5, 5, 6, 5, 3, 4, 4, 6, 6, 5, 4, 4, 7, 5, 8, 6, 9, 4, 8,
#        4, 4, 7, 3, 5, 4, 7, 6, 6, 6, 6, 5, 5, 7, 6, 4, 8, 8, 5, 4, 5, 4,
#        5, 6, 8, 4, 8, 6, 4, 4, 5, 6, 3, 3])
